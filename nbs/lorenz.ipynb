# %%
# Author: Prabhu Ramachandran <prabhu@aero.iitb.ac.in>
# Copyright (c) 2008-2020, Enthought, Inc.
# License: BSD Style.

import numpy
from mayavi import mlab


def lorenz(x, y, z, s=10., r=28., b=8. / 3.):
    """The Lorenz system."""
    u = s * (y - x)
    v = r * x - y - x * z
    w = x * y - b * z
    return u, v, w

# Sample the space in an interesting region.
x, y, z = numpy.mgrid[-50:50:100j, -50:50:100j, -10:60:70j]
u, v, w = lorenz(x, y, z)
fig = mlab.figure(size=(400, 300), bgcolor=(0, 0, 0))

# Plot the flow of trajectories with suitable parameters.
f = mlab.flow(x, y, z, u, v, w, line_width=3, colormap='Paired')
f.module_manager.scalar_lut_manager.reverse_lut = True
f.stream_tracer.integration_direction = 'both'
f.stream_tracer.maximum_propagation = 200
# Uncomment the following line if you want to hide the seed:
#f.seed.widget.enabled = False

# Extract the z-velocity from the vectors and plot the 0 level set
# hence producing the z-nullcline.
src = f.mlab_source.m_data
e = mlab.pipeline.extract_vector_components(src)
e.component = 'z-component'
zc = mlab.pipeline.iso_surface(e, opacity=0.5, contours=[0, ],
            color=(0.6, 1, 0.2))
# When using transparency, hiding 'backface' triangles often gives better
# results
zc.actor.property.backface_culling = True

# A nice view of the plot.
mlab.view(140, 120, 113, [0.65, 1.5, 27])
mlab.show()

# %%
# Copyright (c) 2008-2020, Enthought, Inc.
# License: BSD Style.

import numpy as np
import scipy

from traits.api import HasTraits, Range, Instance, \
        on_trait_change, Array, Tuple, Str
from traitsui.api import View, Item, HSplit, Group

from mayavi import mlab
from mayavi.core.ui.api import MayaviScene, MlabSceneModel, \
    SceneEditor

################################################################################
# `Lorenz` class.
################################################################################
class Lorenz(HasTraits):

    # The parameters for the Lorenz system, defaults to the standard ones.
    s = Range(0.0, 20.0, 10.0, desc='the parameter s', enter_set=True,
              auto_set=False)
    r = Range(0.0, 50.0, 28.0, desc='the parameter r', enter_set=True,
              auto_set=False)
    b = Range(0.0, 10.0, 8./3., desc='the parameter b', enter_set=True,
              auto_set=False)

    # These expressions are evaluated to compute the right hand sides of
    # the ODE.  Defaults to the Lorenz system.
    u = Str('s*(y-x)', desc='the x component of the velocity',
            auto_set=False, enter_set=True)
    v = Str('r*x - y - x*z', desc='the y component of the velocity',
            auto_set=False, enter_set=True)
    w = Str('x*y - b*z', desc='the z component of the velocity',
            auto_set=False, enter_set=True)

    # Tuple of x, y, z arrays where the field is sampled.
    points = Tuple(Array, Array, Array)

    # The mayavi(mlab) scene.
    scene = Instance(MlabSceneModel, args=())

    # The "flow" which is a Mayavi streamline module.
    flow = Instance(HasTraits)

    ########################################
    # The UI view to show the user.
    view = View(HSplit(
                    Group(
                        Item('scene', editor=SceneEditor(scene_class=MayaviScene),
                             height=500, width=500, show_label=False)),
                    Group(
                        Item('s'),
                        Item('r'),
                        Item('b'),
                        Item('u'), Item('v'), Item('w')),
                    ),
                resizable=True
                )

    ######################################################################
    # Trait handlers.
    ######################################################################

    # Note that in the `on_trait_change` call below we listen for the
    # `scene.activated` trait.  This conveniently ensures that the flow
    # is generated as soon as the mlab `scene` is activated (which
    # happens when the configure/edit_traits method is called).  This
    # eliminates the need to manually call the `update_flow` method etc.
    @on_trait_change('s, r, b, scene.activated')
    def update_flow(self):
        x, y, z = self.points
        u, v, w = self.get_uvw()
        self.flow.mlab_source.trait_set(u=u, v=v, w=w)

    @on_trait_change('u')
    def update_u(self):
        self.flow.mlab_source.trait_set(u=self.get_vel('u'))

    @on_trait_change('v')
    def update_v(self):
        self.flow.mlab_source.trait_set(v=self.get_vel('v'))

    @on_trait_change('w')
    def update_w(self):
        self.flow.mlab_source.trait_set(w=self.get_vel('w'))

    def get_uvw(self):
        return self.get_vel('u'), self.get_vel('v'), self.get_vel('w')

    def get_vel(self, comp):
        """This function basically evaluates the user specified system
        of equations using scipy.
        """
        func_str = getattr(self, comp)
        try:
            g = scipy.__dict__
            x, y, z = self.points
            s, r, b = self.s, self.r, self.b
            val = eval(func_str, g,
                        {'x': x, 'y': y, 'z': z,
                         's':s, 'r':r, 'b': b})
        except:
            # Mistake, so return the original value.
            val = getattr(self.flow.mlab_source, comp)
        return val

    ######################################################################
    # Private interface.
    ######################################################################
    def _points_default(self):
        x, y, z = np.mgrid[-50:50:100j,-50:50:100j,-10:60:70j]
        return x, y, z

    def _flow_default(self):
        x, y, z = self.points
        u, v, w = self.get_uvw()
        f = self.scene.mlab.flow(x, y, z, u, v, w)
        f.stream_tracer.integration_direction = 'both'
        f.stream_tracer.maximum_propagation = 200
        src = f.mlab_source.m_data
        o = mlab.outline()
        mlab.view(120, 60, 150)
        return f


if __name__ == '__main__':
    # Instantiate the class and configure its traits.
    lor = Lorenz()
    lor.configure_traits()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\envs\basemap_env\lib\site-packages\traitsui\qt4\ui_base.py in done(self, r)
#     203         if self._result is not None:
#     204             QtGui.QDialog.done(self, self._result)
# --> 205         elif self._ok_to_close(bool(r)):
#     206             QtGui.QDialog.done(self, r)
#     207
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\traitsui\qt4\ui_base.py in _ok_to_close(self, is_ok)
#     220                 is_ok = not self.isModal()
#     221
# --> 222         ok_to_close = self._ui.handler.close(self._ui.info, is_ok)
#     223         if ok_to_close:
#     224             # Save the result now.
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\apptools\preferences\ui\preferences_manager.py in close(self, info, is_ok)
#      96
#      97         if is_ok:
# ---> 98             info.object.apply()
#      99
#     100         return super(PreferencesManagerHandler, self).close(info, is_ok)
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\mayavi\preferences\preference_manager_view.py in apply(self)
#      75         super(PreferenceManagerView, self).apply()
#      76         for page in self.pages:
# ---> 77             page.preferences.save()
#      78
#      79
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\apptools\preferences\scoped_preferences.py in save(self, file_or_filename)
#     334             file_or_filename = self.filename
#     335
# --> 336         self._get_primary_scope().save(file_or_filename)
#     337         for scope in self.scopes:
#     338             if scope is not self._get_primary_scope():
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\apptools\preferences\preferences.py in save(self, file_or_filename)
#     394             config_obj = ConfigObj(file_or_filename, encoding="utf-8")
#     395             self._add_node_to_dictionary(self, config_obj)
# --> 396             config_obj.write()
#     397
#     398     ###########################################################################
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\configobj.py in write(self, outfile, section)
#    2126             outfile.write(output_bytes)
#    2127         else:
# -> 2128             with open(self.filename, 'wb') as h:
#    2129                 h.write(output_bytes)
#    2130
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Carlos\\AppData\\Roaming\\Enthought\\mayavi_e3\\preferences.ini'

# %%
from mayavi import mlab
import numpy as np
import os

# Output path for you animation images
out_path = './'
out_path = os.path.abspath(out_path)
fps = 20
prefix = 'ani'
ext = '.png'

# Produce some nice data.
n_mer, n_long = 6, 11
pi = np.pi
dphi = pi/1000.0
phi = np.arange(0.0, 2*pi + 0.5*dphi, dphi, 'd')
mu = phi*n_mer
x = np.cos(mu)*(1+np.cos(n_long*mu/n_mer)*0.5)
y = np.sin(mu)*(1+np.cos(n_long*mu/n_mer)*0.5)
z = np.sin(n_long*mu/n_mer)*0.5

# Init plot
plt = mlab.points3d(x[0], y[0], z[0])

padding = len(str(len(x)))

# Define data source and update routine
msplt = plt.mlab_source
@mlab.animate(delay=10)
def anim():
    f = mlab.gcf()
    for i in range(len(x)):
        #animation updates here
        msplt.set(x=x[i], y=y[i], z=z[i])

        # create zeros for padding index positions for organization
        zeros = '0'*(padding - len(str(i)))

        # concate filename with zero padded index number as suffix
        filename = os.path.join(out_path, '{}_{}{}{}'.format(prefix, zeros, i, ext))

        mlab.savefig(filename=filename)

        yield

anim()
mlab.view(distance=15)
mlab.show()

import subprocess
ffmpeg_fname = os.path.join(out_path, '{}_%0{}d{}'.format(prefix, padding, ext))
cmd = 'ffmpeg -f image2 -r {} -i {} -vcodec mpeg4 -y {}.mp4'.format(fps,
                                                                    ffmpeg_fname,
                                                                    prefix)
print (cmd)
subprocess.check_output(['bash','-c', cmd])

# Remove temp image files with extension
[os.remove(f) for f in os.listdir(out_path) if f.endswith(ext)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\envs\basemap_env\lib\site-packages\mayavi\tools\figure.py in savefig(filename, size, figure, magnification, **kwargs)
#     249                           size=size,
# --> 250                           **kwargs)
#     251     finally:
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\tvtk\pyface\tvtk_scene.py in save(self, file_name, size, **kw_args)
#     431         else:
# --> 432             meth(file_name, **kw_args)
#     433             self._record_methods('save(%r)'%(file_name))
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\tvtk\pyface\tvtk_scene.py in save_png(self, file_name)
#     469             configure_input(ex, w2if)
# --> 470             self._exporter_write(ex)
#     471
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\tvtk\pyface\tvtk_scene.py in _exporter_write(self, ex)
#     876         else:
# --> 877             aa_frames = rw.multi_samples
#     878             rw.multi_samples = self.anti_aliasing_frames
#
# AttributeError: 'NoneType' object has no attribute 'multi_samples'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\envs\basemap_env\lib\site-packages\pyface\timer\i_timer.py in perform(self)
#     199
#     200         try:
# --> 201             self._perform()
#     202         except StopIteration:
#     203             self.stop()
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\pyface\timer\i_timer.py in _perform(self)
#     298     def _perform(self):
#     299         """ Perform the callback. """
# --> 300         self.callback(*self.args, **self.kwargs)
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\mayavi\tools\animator.py in _step(self)
#     221         def _step(self):
#     222             try:
# --> 223                 self._next()
#     224                 if self._support_movie:
#     225                     self._update_movie_maker()
#
# <ipython-input-4-0fc9961130ef> in anim()
#      40         filename = os.path.join(out_path, '{}_{}{}{}'.format(prefix, zeros, i, ext))
#      41
# ---> 42         mlab.savefig(filename=filename)
#      43
#      44         yield
#
# ~\anaconda3\envs\basemap_env\lib\site-packages\mayavi\tools\figure.py in savefig(filename, size, figure, magnification, **kwargs)
#     250                           **kwargs)
#     251     finally:
# --> 252         figure.scene.magnification = int(current_mag)
#     253
#     254
#
# AttributeError: 'NoneType' object has no attribute 'magnification'
# ffmpeg -f image2 -r 20 -i C:\Users\Carlos\Desktop\lorentz multianim\ani_%04d.png -vcodec mpeg4 -y ani.mp4
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-4-0fc9961130ef> in <module>
#      54                                                                     prefix)
#      55 print (cmd)
# ---> 56 subprocess.check_output(['bash','-c', cmd])
#      57
#      58 # Remove temp image files with extension
#
# ~\anaconda3\envs\basemap_env\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     409
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#     413
#
# ~\anaconda3\envs\basemap_env\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     510         if check and retcode:
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#     514
#
# CalledProcessError: Command '['bash', '-c', 'ffmpeg -f image2 -r 20 -i C:\\Users\\Carlos\\Desktop\\lorentz multianim\\ani_%04d.png -vcodec mpeg4 -y ani.mp4']' returned non-zero exit status 127.
